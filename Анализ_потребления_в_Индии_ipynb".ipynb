# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexZakharov1978/Inno/blob/main/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%BF%D0%BE%D1%82%D1%80%D0%B5%D0%B1%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2_%D0%98%D0%BD%D0%B4%D0%B8%D0%B8_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Подключаем ГуДиск

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Импортируем бибилиотеки и грузим датасет

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data=pd.read_csv('/content/drive/MyDrive/Datasets/dataset_tk.csv',index_col=0)
data
# Out:
#                      Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
# ...                     ...      ...        ...    ...    ...          ...
# 01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8         36.5
# 02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4         37.0
# 03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7         37.8
# 04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6         38.2
# 05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3         35.2
#
# ...

# %%
data.describe(include = "all")
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000
# mean   141.145527  138.333598  218.443340   83.380716  314.036382
# std     56.977361   38.106593   27.421615   25.915357   66.516960
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.000000  114.800000  205.800000   63.500000  263.650000
# 50%    118.300000  126.800000  222.900000   72.700000  290.000000
# 75%    162.500000  158.100000  237.600000  105.800000  370.550000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   503.000000  503.000000  503.000000  503.000000    503.000000  ...
# mean     36.157058   26.568191   44.264016    4.141551     83.877137  ...
# std       6.705108    4.807040    4.769391    1.143422     10.130427  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# ...

# %%
data['Punjab'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 3. Построим графики потребления по штатам

# %%
data.plot.line(y=['Delhi', 'Punjab', 'Haryana'], figsize=(22,6))
# Out:
# <Axes: >

# %%
data.plot.area(figsize=(22,6))
# Out:
# <Axes: >

# %%
data.plot.line(y=['Tripura', 'UP', 'Uttarakhand'], figsize=(22,6))
# Out:
# <Axes: >

# %% [markdown]
# # Новый раздел
